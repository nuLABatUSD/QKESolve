# %%
import SOLVING_QKE_FUNCTION as solve
import numpy as np
import derivatives as der

# %%
N=200
Emax= 10
Eval= np.linspace(Emax/N, Emax, N)
ym0 = np.zeros((N,4))
for i in range(len(ym0)):
    p0 = 1/(np.exp(Eval[i])+1)
    ym0[i,:] = [p0,0,0,1]
ym0_bar= np.zeros((N,4))
for i in range(len(ym0_bar)):
    p0= 1/(np.exp(Eval[i])+1)
    ym0_bar[i,:]= [p0,0,0,1]

# %%
# %%time
T = [0.12, 0.25, 0.44, 1, 2, 4]

foldername = "DataRun2"
basename = "Run"

y0 = der.newarray_maker(ym0,ym0_bar)
for i in range(len(T)):
#    %time solve.solve_QKE(T[i], y0, True, True, foldername, basename + '2{}'.format(i), incl_collisions=False)
    # %time solve.solve_QKE(T[i], y0, True, True, foldername, basename + '3{}'.format(i), incl_collisions=True)
# Out:
# Data saved to file DataRun2/Run30.npz
# 905 time steps saved with dN = 5
# incl_thermal_term True
# incl_anti_neutrinos True
# incl_collisions True
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 0.12
# CPU times: user 22.4 s, sys: 95.8 ms, total: 22.5 s
# Wall time: 22.5 s
# Data saved to file DataRun2/Run31.npz
# 906 time steps saved with dN = 5
# incl_thermal_term True
# incl_anti_neutrinos True
# incl_collisions True
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 0.25
# CPU times: user 9.37 s, sys: 22.7 ms, total: 9.4 s
# Wall time: 9.39 s
# Data saved to file DataRun2/Run32.npz
# 923 time steps saved with dN = 5
# incl_thermal_term True
# incl_anti_neutrinos True
# incl_collisions True
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 0.44
# CPU times: user 9.98 s, sys: 23.6 ms, total: 10 s
# Wall time: 10 s
# Data saved to file DataRun2/Run33.npz
# 624 time steps saved with dN = 15
# incl_thermal_term True
# ...

# %%
# %%time

foldername = "DataRun1"
basename = "Run"

y0 = der.newarray_maker(ym0,ym0_bar)
# Out:
# CPU times: user 340 ms, sys: 33.4 ms, total: 373 ms
# Wall time: 395 ms

# %%
# %%time
solve.solve_QKE(8, y0, True, True, foldername, "Run36", incl_collisions=True)
# Out:
# Data saved to file DataRun2/Run36.npz
# 101 time steps saved with dN = 3240
# incl_thermal_term True
# incl_anti_neutrinos True
# incl_collisions True
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 8
# CPU times: user 13min 30s, sys: 2.24 s, total: 13min 32s
# Wall time: 13min 31s

# %%
# %%time
solve.solve_QKE(8, y0, True, True, foldername, "Run26", incl_collisions=False)
# Out:
# Data saved to file DataRun1/Run26.npz
# 93 time steps saved with dN = 3245
# incl_thermal_term True
# incl_anti_neutrinos True
# incl_collisions False
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 8
# CPU times: user 10min 29s, sys: 1.77 s, total: 10min 31s
# Wall time: 10min 30s

# %%
# %%time
solve.solve_QKE(8, y0, False, True, foldername, "Run16", incl_collisions=collisions=collisions=collisions=collisions=collisions=_collisions=True)
# Out:
# Data saved to file DataRun1/Run16.npz
# 724 time steps saved with dN = 570
# incl_thermal_term False
# incl_anti_neutrinos True
# incl_collisions True
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 8
# CPU times: user 15min 22s, sys: 2.59 s, total: 15min 25s
# Wall time: 15min 23s

# %%
# %%time
solve.solve_QKE(8, y0, False, True, foldername, "Run06", incl_collisions=False)
# Out:
# Data saved to file DataRun1/Run06.npz
# 992 time steps saved with dN = 525
# incl_thermal_term False
# incl_anti_neutrinos True
# incl_collisions False
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 8
# CPU times: user 15min 27s, sys: 1.81 s, total: 15min 29s
# Wall time: 15min 28s

# %%
# %%time
TT = [16, 32, 64, 128]

for i in range(len(TT)):
    # %time solve.solve_QKE(TT[i], y0, True, True, foldername, basename + '3{}'.format(i+7), incl_collisions=True)
# Out:
# Data saved to file DataRun1/Run37.npz
# 23 time steps saved with dN = 92360
# incl_thermal_term True
# incl_anti_neutrinos True
# incl_collisions True
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 16
# CPU times: user 1h 17min 55s, sys: 8.43 s, total: 1h 18min 4s
# Wall time: 1h 17min 59s
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ERROR:  10 iterations without acceptable step
# ...
