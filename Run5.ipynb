# %%
import numpy as np
import matplotlib.pyplot as plt
import Solve_Thermal as ST
import SOLVING_QKE_FUNCTION as solve

# %%
T = [0.12, 0.25, 0.44, 1, 2, 4, 8]

foldername = "DataRun4"

eta_e = 0.01
eta_mu = -0.01

y0 = ST.make_ics_eqm(200,10,eta_e, eta_mu)

# %%
# %%time
ind = 0
solve.solve_QKE(T[ind], y0, True, True, foldername, "Run5{}".format(ind), tau_final = 5, incl_collisions = True, incl_eta = True, eta_e = eta_e, eta_mu = eta_mu)
ST.solve_series(foldername, "Run5{}".format(ind), 25, 6)
# Out:
# Data saved to file DataRun4/Run51.npz
# 483 time steps saved with dN = 5
# incl_thermal_term True
# incl_anti_neutrinos True
# incl_collisions True
# incl_eta True
# eta_e 0.1
# eta_mu -0.1
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 0.12
# Solve from $\tau$ = 4.999999999999999 to $\tau$ = 9.0
# Time elapse, 5.4 seconds
# Solve from $\tau$ = 9.0 to $\tau$ = 13.0
# Time elapse, 4.0 seconds
# Solve from $\tau$ = 13.0 to $\tau$ = 17.0
# Time elapse, 4.0 seconds
# Solve from $\tau$ = 17.0 to $\tau$ = 21.0
# Time elapse, 4.0 seconds
# Solve from $\tau$ = 21.0 to $\tau$ = 25.0
# Time elapse, 4.1 seconds
# CPU times: user 41.3 s, sys: 199 ms, total: 41.5 s
# Wall time: 41.5 s
