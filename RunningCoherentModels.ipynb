# %%
import numpy as np
import matplotlib.pyplot as plt
import ODESolve as ODE
import derivatives as der

import os

from solveQKEs import solve_all_electron_ic, prob_plot

# %%
T = [0.12, 0.25, 0.44, 1, 2]

foldername = "CoherentRun-All-ve"
basename = "Run"

for i in range(len(T)):
    # %time solve_all_electron_ic(T[i], False, True, foldername, basename + '0{}'.format(i), N=200)
    # %time solve_all_electron_ic(T[i], True, True, foldername, basename + '1{}'.format(i), N=200)
# Out:
# Data saved to file CoherentRun-All-ve/Run00.npz
# 905 time steps saved with dN = 5
# incl_thermal_term False
# incl_anti_neutrinos True
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 0.12
# CPU times: user 8.09 s, sys: 22.3 ms, total: 8.12 s
# Wall time: 8.11 s
# Data saved to file CoherentRun-All-ve/Run10.npz
# 905 time steps saved with dN = 5
# incl_thermal_term True
# incl_anti_neutrinos True
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 0.12
# CPU times: user 8.34 s, sys: 17.6 ms, total: 8.36 s
# Wall time: 8.35 s
# Data saved to file CoherentRun-All-ve/Run01.npz
# 906 time steps saved with dN = 5
# incl_thermal_term False
# incl_anti_neutrinos True
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 0.25
# CPU times: user 8.53 s, sys: 19 ms, total: 8.55 s
# Wall time: 8.54 s
# Data saved to file CoherentRun-All-ve/Run11.npz
# 906 time steps saved with dN = 5
# incl_thermal_term True
# ...

# %%
# %time solve_all_electron_ic(4, False, True, foldername, basename + '05', N=200)
# %time solve_all_electron_ic(4, True, True, foldername, basename + '15', N=200)
# Out:
# Data saved to file CoherentRun-All-ve/Run05.npz
# 931 time steps saved with dN = 140
# incl_thermal_term False
# incl_anti_neutrinos True
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 4
# CPU times: user 3min 54s, sys: 412 ms, total: 3min 54s
# Wall time: 3min 54s
# Data saved to file CoherentRun-All-ve/Run15.npz
# 723 time steps saved with dN = 170
# incl_thermal_term True
# incl_anti_neutrinos True
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 4
# CPU times: user 3min 43s, sys: 321 ms, total: 3min 43s
# Wall time: 3min 43s

# %%
T = [0.12, 0.25, 0.44, 1, 2]

foldername = "CoherentRun-no-anti"
basename = "Run"

for i in range(len(T)):
    # %time solve_all_electron_ic(T[i], False, False, foldername, basename + '0{}'.format(i), N=200)
    # %time solve_all_electron_ic(T[i], True, False, foldername, basename + '1{}'.format(i), N=200)
# Out:
# Data saved to file CoherentRun-no-anti/Run00.npz
# 898 time steps saved with dN = 5
# incl_thermal_term False
# incl_anti_neutrinos False
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 0.12
# CPU times: user 4.7 s, sys: 19.9 ms, total: 4.72 s
# Wall time: 4.72 s
# Data saved to file CoherentRun-no-anti/Run10.npz
# 898 time steps saved with dN = 5
# incl_thermal_term True
# incl_anti_neutrinos False
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 0.12
# CPU times: user 3.95 s, sys: 9.82 ms, total: 3.96 s
# Wall time: 3.95 s
# Data saved to file CoherentRun-no-anti/Run01.npz
# 803 time steps saved with dN = 5
# incl_thermal_term False
# incl_anti_neutrinos False
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 0.25
# CPU times: user 3.51 s, sys: 8.39 ms, total: 3.52 s
# Wall time: 3.51 s
# Data saved to file CoherentRun-no-anti/Run11.npz
# 803 time steps saved with dN = 5
# incl_thermal_term True
# ...

# %%
# %time solve_all_electron_ic(4, False, False, foldername, basename + '05', N=200)
# %time solve_all_electron_ic(4, True, False, foldername, basename + '15', N=200)
# Out:
# Data saved to file CoherentRun-no-anti/Run05.npz
# 365 time steps saved with dN = 71715
# incl_thermal_term False
# incl_anti_neutrinos False
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 4
# CPU times: user 6h 13min 5s, sys: 1min, total: 6h 14min 6s
# Wall time: 6h 13min 21s
# Data saved to file CoherentRun-no-anti/Run15.npz
# 353 time steps saved with dN = 73590
# incl_thermal_term True
# incl_anti_neutrinos False
# N 200
# eps_max 10
# delta m-squared 2.5e-15
# sin^2 (2theta) 0.8
# T 4
# CPU times: user 6h 1min 51s, sys: 36.5 s, total: 6h 2min 28s
# Wall time: 6h 2min 12s
